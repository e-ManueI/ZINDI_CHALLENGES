# %% [markdown]
# <h2><center> Welcome to the Ernst & Young Carbon Prediction Hackathon</h2></center>
# <figure>
# <!-- <center><img src ="https://drive.google.com/uc?export=view&id=1hSOAfRhJ_jo-MZAjq81VYJu5bZNL7EjD" width = "800" height = '500'/> -->
#
# *About the problem*
# > The ability to accurately monitor carbon emissions is a critical step in the fight against climate change. Precise carbon readings allow researchers and governments to understand the sources and patterns of carbon mass output. While Europe and North America have extensive systems in place to monitor carbon emissions on the ground, there are few available in Africa.
#
# *Objective of this challenge*
# > The objective of this challenge is to create machine learning or a deep learning model using open-source CO2 emissions data (from Sentinel-5P satellite observations) to predict carbon emissions.
#
# These solutions will enable EY, governments, and other actors to estimate carbon emission levels across Africa, even in places where on-the-ground monitoring is not possible.

# %% [markdown]
# ## Table of contents:
#
# 1. [Installing and importing libraries](#Libraries)
# 2. [Loading data](#Data)
# 3. [Statistical summaries](#Statistics)
# 4. [Outliers](#Outliers)
# 5. [Geo Visualisation - EDA](#Geo)
# 5. [Missing values and duplicates](#Missing)
# 6. [Date features EDA](#Dates)
# 7. [Correlations - EDA](#Correlations)
# 9. [Timeseries visualization - EDA](#Timeseries)
# 10. [Feature engineering](#Engineering)
# 11. [Modelling](#Modelling)
# 12. [Making predictions of the test set and creating a submission file](#Predictions)

# %% [markdown]
# <a name="Libraries"></a>
# ## 1. Installing and importing libraries

# %%
# %%capture
# Install relevant libraries
# !pip install geopandas folium

# %%
# Import libraries
import pandas as pd
import numpy as np
import random
import os
from tqdm.notebook import tqdm

import geopandas as gpd
from shapely.geometry import Point
import folium

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from scipy import stats
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
pd.options.display.float_format = '{:.5f}'.format
pd.options.display.max_rows = None

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Set seed for reproducability
SEED = 2023
random.seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# <a name="Data"></a>
# ## 2. Loading and previewing data

# %%
DATA_PATH = ''
# Load files
train = pd.read_csv(os.path.join(DATA_PATH, 'Train.csv'))
test = pd.read_csv(os.path.join(DATA_PATH, 'Test.csv'))
samplesubmission = pd.read_csv(os.path.join(DATA_PATH, 'SampleSubmission.csv'))

# Preview train dataset
train.head()
# Out:
#      ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-23.73_28.77_2019_1 -23.73000   28.77000  2019        1
# 1  ID_-23.73_28.77_2019_2 -23.73000   28.77000  2019        2
# 2  ID_-23.73_28.77_2019_3 -23.73000   28.77000  2019        3
# 3  ID_-23.73_28.77_2019_4 -23.73000   28.77000  2019        4
# 4  ID_-23.73_28.77_2019_5 -23.73000   28.77000  2019        5
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                   0.00017
# 1                                  -0.00016
# 2                                  -0.00007
# 3                                   0.00015
# 4                                   0.00002
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                       0.71317
# 1                                       0.81291
# 2                                       0.86031
# 3                                       0.42228
# 4                                       1.00458
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                         0.00010
# 1                                        -0.00014
# 2                                        -0.00006
# 3                                         0.00009
# 4                                         0.00003
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  ...  \
# 0                        0.22393                             24.93944  ...
# 1                        0.08028                             16.62416  ...
# 2                        0.16105                            -13.23724  ...
# 3                        0.04650                            -13.53465  ...
# 4                        0.21425                            -13.47572  ...
#
#    Cloud_cloud_top_height  Cloud_cloud_base_pressure  Cloud_cloud_base_height  \
# 0              5566.22202                54826.03262               4606.20999
# 1              3711.51137                68491.75334               3034.46166
# 2              2136.38519                78967.73955               1433.48259
# 3              3841.85302                64592.80677               2878.51292
# 4              1295.68817                86804.02539               1094.66534
#
#    Cloud_cloud_optical_depth  Cloud_surface_albedo  \
# 0                   19.11528               0.35378
# 1                   12.21866               0.24499
# 2                    6.06274               0.24510
# 3                    6.38823               0.21090
# 4                    9.20625               0.26110
#
#    Cloud_sensor_azimuth_angle  Cloud_sensor_zenith_angle  \
# 0                    24.95195                   49.05395
# 1                     4.70886                   42.58668
# 2                    76.06063                   34.73754
# 3                    75.91237                   60.29449
# 4                   -13.34608                   50.19449
#
#    Cloud_solar_azimuth_angle  Cloud_solar_zenith_angle  emission
# 0                  -89.63803                  17.98887  86.05170
# 1                  -89.90431                  22.77325  88.87567
# 2                  -83.59525                  17.43730  91.72311
# 3                  -71.89673                  11.97782  92.88387
# 4                  -77.46208                  24.37427  94.87833
#
# [5 rows x 76 columns]

# %%
# Preview test dataset
test.head()
# Out:
#      ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-23.53_27.47_2019_1 -23.53000   27.47000  2019        1
# 1  ID_-23.53_27.47_2019_2 -23.53000   27.47000  2019        2
# 2  ID_-23.53_27.47_2019_3 -23.53000   27.47000  2019        3
# 3  ID_-23.53_27.47_2019_4 -23.53000   27.47000  2019        4
# 4  ID_-23.53_27.47_2019_5 -23.53000   27.47000  2019        5
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                   0.00008
# 1                                   0.00018
# 2                                   0.00006
# 3                                   0.00048
# 4                                   0.00019
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                       0.45447
# 1                                       0.42317
# 2                                       0.71309
# 3                                       0.43445
# 4                                       0.78304
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                         0.00003
# 1                                         0.00006
# 2                                         0.00004
# 3                                         0.00017
# 4                                         0.00014
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  ...  \
# 0                        0.11429                            -80.28631  ...
# 1                        0.07510                            -17.76569  ...
# 2                        0.11421                             16.72565  ...
# 3                        0.13139                            -22.47534  ...
# 4                        0.16114                              4.75036  ...
#
#    Cloud_cloud_top_pressure  Cloud_cloud_top_height  \
# 0               74897.05200              2180.26654
# 1               84222.65352               982.61906
# 2               78922.49079              1582.96493
# 3               61135.91959              3935.41998
# 4               78494.24739              1647.53853
#
#    Cloud_cloud_base_pressure  Cloud_cloud_base_height  \
# 0                81287.07448               1562.03102
# 1                90307.65001                927.11122
# 2                85383.15185               1006.77811
# 3                67490.03136               3428.42353
# 4                84478.74304               1122.53409
#
#    Cloud_cloud_optical_depth  Cloud_surface_albedo  \
# 0                   10.73412               0.28066
# 1                    5.25002               0.23893
# 2                    6.81937               0.25868
# 3                    6.23363               0.28154
# 4                   11.81025               0.28156
#
#    Cloud_sensor_azimuth_angle  Cloud_sensor_zenith_angle  \
# 0                   -31.23017                   33.33797
# 1                    66.49090                   58.13779
# 2                    75.92319                   41.33695
# 3                   -11.02323                   60.68987
# 4                   -13.29451                   51.00713
#
#    Cloud_solar_azimuth_angle  Cloud_solar_zenith_angle
# 0                  -93.21726                  23.35825
# 1                  -85.00147                  13.41648
# 2                  -83.26754                  16.27300
# 3                  -77.76372                  22.79396
# 4                  -76.62065                  23.19824
#
# [5 rows x 75 columns]

# %%
# Preview sample submission file
samplesubmission.head()
# Out:
#      ID_LAT_LON_YEAR_WEEK  emission
# 0  ID_-23.53_27.47_2019_1         0
# 1  ID_-23.53_27.47_2019_2         0
# 2  ID_-23.53_27.47_2019_3         0
# 3  ID_-23.53_27.47_2019_4         0
# 4  ID_-23.53_27.47_2019_5         0

# %%
# Check size and shape of datasets
train.shape, test.shape, samplesubmission.shape
# Out:
# ((74005, 76), (28085, 75), (28085, 2))

# %%
# Train to test sets ratio
(test.shape[0]) / (train.shape[0] + test.shape[0])
# Out:
# 0.2751004016064257

# %% [markdown]
# <a name="Statistics"></a>
# ## 3. Statistical summaries

# %%
# Train statistical summary
train.describe(include = 'all')
# Out:
#           ID_LAT_LON_YEAR_WEEK    latitude   longitude        year  \
# count                    74005 74005.00000 74005.00000 74005.00000
# unique                   74005         NaN         NaN         NaN
# top     ID_-23.73_28.77_2019_1         NaN         NaN         NaN
# freq                         1         NaN         NaN         NaN
# mean                       NaN   -27.82972    27.78274  2020.47805
# std                        NaN     2.76059     2.74667     1.11126
# min                        NaN   -33.93000    21.07000  2019.00000
# 25%                        NaN   -29.63000    26.67000  2019.00000
# 50%                        NaN   -28.13000    28.77000  2020.00000
# 75%                        NaN   -25.73000    29.47000  2021.00000
# max                        NaN   -23.73000    31.17000  2022.00000
#
#            week_no  SulphurDioxide_SO2_column_number_density  \
# count  74005.00000                               72075.00000
# unique         NaN                                       NaN
# top            NaN                                       NaN
# freq           NaN                                       NaN
# mean      26.15610                                   0.00026
# std       14.84384                                   0.00060
# min        1.00000                                  -0.00099
# 25%       13.00000                                  -0.00007
# 50%       26.00000                                   0.00015
# 75%       39.00000                                   0.00044
# max       52.00000                                   0.00953
#
#         SulphurDioxide_SO2_column_number_density_amf  \
# count                                    72075.00000
# unique                                           NaN
# top                                              NaN
# freq                                             NaN
# mean                                         0.51587
# std                                          0.19677
# min                                          0.13374
# 25%                                          0.37174
# 50%                                          0.48869
# 75%                                          0.62353
# max                                          1.67341
#
#         SulphurDioxide_SO2_slant_column_number_density  \
# count                                      72075.00000
# unique                                             NaN
# top                                                NaN
# freq                                               NaN
# mean                                           0.00009
# std                                            0.00020
# min                                           -0.00083
# 25%                                           -0.00003
# 50%                                            0.00007
# 75%                                            0.00019
# max                                            0.00187
#
#         SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  \
# count                     72075.00000                          72075.00000
# unique                            NaN                                  NaN
# top                               NaN                                  NaN
# freq                              NaN                                  NaN
# mean                          0.10569                              4.48763
# std                           0.06955                             52.24654
# min                           0.00000                           -110.02766
# 25%                           0.05248                            -18.17813
# 50%                           0.09951                            -10.98754
# 75%                           0.15248                             59.11999
# max                           0.29999                             83.74398
#
#         ...  Cloud_cloud_top_height  Cloud_cloud_base_pressure  \
# count   ...             71281.00000                71281.00000
# unique  ...                     NaN                        NaN
# top     ...                     NaN                        NaN
# freq    ...                     NaN                        NaN
# mean    ...              3652.34972                74390.62446
# std     ...              1807.38528                12859.06733
# min     ...               128.29979                14541.97799
# 25%     ...              2260.91745                65920.34050
# 50%     ...              3437.87891                75994.80202
# 75%     ...              4745.60794                84409.69113
# max     ...             15674.42415               102267.15098
#
#         Cloud_cloud_base_height  Cloud_cloud_optical_depth  \
# count               71281.00000                71281.00000
# unique                      NaN                        NaN
# top                         NaN                        NaN
# freq                        NaN                        NaN
# mean                 2871.26282                   15.82539
# std                  1645.82767                   19.69665
# min                    10.30036                    1.15114
# 25%                  1602.61523                    5.07185
# 50%                  2563.92629                    8.60904
# 75%                  3819.67139                   17.47863
# max                 14674.42321                  250.00000
#
#         Cloud_surface_albedo  Cloud_sensor_azimuth_angle  \
# count            71281.00000                 71281.00000
# unique                   NaN                         NaN
# top                      NaN                         NaN
# freq                     NaN                         NaN
# mean                 0.22544                   -14.27712
# std                  0.06313                    47.27732
# min                  0.00000                  -125.29806
# 25%                  0.18349                   -31.95209
# 50%                  0.22350                   -13.73803
# 75%                  0.26772                     3.79039
# max                  0.75433                   127.48316
#
#         Cloud_sensor_zenith_angle  Cloud_solar_azimuth_angle  \
# count                 71281.00000                71281.00000
# unique                        NaN                        NaN
# top                           NaN                        NaN
# freq                          NaN                        NaN
# mean                     49.56784                  -50.51322
# std                      12.09742                   20.62391
# min                       0.10088                  -97.57091
# 25%                      41.32913                  -67.98772
# 50%                      53.23303                  -45.41392
# 75%                      59.47813                  -33.12496
# max                      66.56461                  -14.17002
#
#         Cloud_solar_zenith_angle      emission
# count                71281.00000   74005.00000
# unique                       NaN           NaN
# top                          NaN           NaN
# freq                         NaN           NaN
# mean                    40.55896    7891.06097
# std                     12.20118   52571.60466
# min                     10.90623       0.04806
# 25%                     29.78659     154.54720
# 50%                     40.11757     723.13586
# 75%                     51.44570    2773.02930
# max                     69.60511 1181701.20000
#
# [11 rows x 76 columns]

# %% [markdown]
# From the above statistical summary, we can deduce some of the following insights:
#  - The train data provided ranges from year *2019 to 2022*
#  - Minimum recorded CO2 emissions is *0.04806* and a maximum of *1181701.2*
#  - Week of the year starts from 1 to 52
#  - The latitude and longitudes ranges show that the regions are mostly within South Africa

# %%
# Target variable distribution
sns.set_style('darkgrid')
plt.figure(figsize = (13, 7))
sns.histplot(train.emission, kde = True, bins = 15)
plt.title('Target variable distribution', y = 1.02, fontsize = 15)
display(plt.show(), train.emission.skew())
# Out:
# None
# 17.038027449698163

# %% [markdown]
# The target variable is skewed to the right with a a degree of ~17.
#
# Some of the techniques used to handle skewness include:
# - Log transform
# - Box-cox transform
# - Square root transform
# - *etc*

# %%
# Target corrections using box-cox
# data = train.emission
# transformed_data, lambda_ = stats.boxcox(data)

# # Target variable distribution
# sns.set_style('darkgrid')
# plt.figure(figsize = (13, 7))
# sns.histplot(transformed_data, kde = True, bins = 15)
# plt.title('Target variable distribution', y = 1.02, fontsize = 15)
# plt.xlabel('Emissions')
# display(plt.show(), pd.DataFrame(transformed_data).skew());
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[152], line 3
#       1 # Target corrections using box-cox
#       2 data = train.emission
# ----> 3 transformed_data, lambda_ = stats.boxcox(data)
#       5 # Target variable distribution
#       6 sns.set_style('darkgrid')
#
# NameError: name 'stats' is not defined

# %%
# Overwrite the train.emission columns with the transformed data
# train.emission = pd.DataFrame(transformed_data)

# %% [markdown]
# <a name="Outliers"></a>
# ## 4. Outliers

# %%
# Plotting boxplot for the CO2 emissions
sns.set_style('darkgrid')
plt.figure(figsize = (13, 7))
sns.boxplot(train.emission)
plt.title('Boxplot showing CO2 emission outliers', y = 1.02, fontsize = 15)  
plt.show()

# %% [markdown]
# Outliers are those data points which differ significantly from other observations present in given dataset.
#
# Suggestions on how to handle outliers:
#  - Transforming the outliers by scaling - log transformation, box-cox transformation ...
#  - Dropping outliers
#  - Imputation by replacing outliers with mean, median ...

# %%
# Drop the outliers
# Filter the data to keep only values below the upper bound
train = train[train.emission <= 0.59e6]

# %%
# Plotting boxplot for the CO2 emissions
sns.set_style('darkgrid')
plt.figure(figsize = (13, 7))
sns.boxplot(train.emission)
plt.title('Boxplot showing CO2 emission outliers', y = 1.02, fontsize = 15)  
plt.show()

# %%
X = train.drop(columns=['emission', 'ID_LAT_LON_YEAR_WEEK'], axis=1)
y = train.emission
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size = 0.3, random_state = SEED)

# Function for comparing different approaches
def score_dataset(X_train, X_valid, y_train, y_valid):
    model = RandomForestRegressor(n_estimators=100, random_state=SEED, n_jobs=-1)
    model.fit(X_train, y_train)
    preds = model.predict(X_valid)
    return mean_squared_error(y_valid, preds, squared=False)

# %% [markdown]
# #### Imputation plain

# %%
my_imputer = SimpleImputer()
imputed_X_train = pd.DataFrame(my_imputer.fit_transform(X_train))
imputed_X_valid = pd.DataFrame(my_imputer.transform(X_valid))

# Fill in the lines below: imputation removed column names; put them back
imputed_X_train.columns = X_train.columns
imputed_X_valid.columns = X_valid.columns

# %% [markdown]
# #### Strategy 2 with median

# %% [markdown]
# <a name="Geo"></a>
# ## 5. Geo Visualisation - EDA

# %%
# Combine train and test for easy visualisation
train_coords = train.drop_duplicates(subset = ['latitude', 'longitude'])
test_coords = test.drop_duplicates(subset = ['latitude', 'longitude'])
train_coords['set_type'], test_coords['set_type'] = 'train', 'test'

all_data = pd.concat([train_coords, test_coords], ignore_index = True)
# Create point geometries

geometry = gpd.points_from_xy(all_data.longitude, all_data.latitude)
geo_df = gpd.GeoDataFrame(
    all_data[["latitude", "longitude", "set_type"]], geometry=geometry
)

# Preview the geopandas df
geo_df.head()
# Out:
#    latitude  longitude set_type                    geometry
# 0 -23.73000   28.77000    train  POINT (28.77000 -23.73000)
# 1 -23.73000   28.87000    train  POINT (28.87000 -23.73000)
# 2 -23.73000   28.97000    train  POINT (28.97000 -23.73000)
# 3 -23.73000   29.07000    train  POINT (29.07000 -23.73000)
# 4 -23.73000   29.17000    train  POINT (29.17000 -23.73000)

# %%
# Create a canvas to plot your map on
all_data_map = folium.Map(prefer_canvas=True)

# Create a geometry list from the GeoDataFrame
geo_df_list = [[point.xy[1][0], point.xy[0][0]] for point in geo_df.geometry]

# Iterate through list and add a marker for each volcano, color-coded by its type.
i = 0
for coordinates in geo_df_list:
    # assign a color marker for the type set
    if geo_df.set_type[i] == "train":
        type_color = "green"
    elif geo_df.set_type[i] == "test":
        type_color = "orange"

    # Place the markers 
    all_data_map.add_child(
        folium.CircleMarker(
            location=coordinates,
            radius = 1,
            weight = 4,
            zoom =10,
            popup= 
            "Set: " + str(geo_df.set_type[i]) + "<br>"
            "Coordinates: " + str([round(x, 2) for x in geo_df_list[i]]),
            color =  type_color),
        )
    i = i + 1
all_data_map.fit_bounds(all_data_map.get_bounds())
all_data_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_64bc05bbd9693d8aeacf089e409b0a8c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_64bc05bbd9693d8aeacf089e409b0a8c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_64bc05bbd9693d8aeacf089e409b0a8c = L.map(
#                 &quot;map_64bc05bbd9693d8aeacf089e409b0a8c&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03207bc2fe0c4f5313b08b54b6ae2901 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_64bc05bbd9693d8aeacf089e409b0a8c);
#
#
#             var circle_marker_3622527d8ee644ac46a1264ed23e2609 = L.circleMarker(
#                 [-23.73, 28.77],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(map_64bc05bbd9693d8aeacf089e409b0a8c);
#
#
#         var popup_4f27f5cb124ee12ac03d1dfb71c4b456 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4e73d982a373240864d1a58fc5b5875b = $(`&lt;div id=&quot;html_4e73d982a373240864d1a58fc5b5875b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Set: train&lt;br&gt;Coordinates: [-23.73, 28.77]&lt;/div&gt;`)[0];
#                 popup_4f27f5cb124ee12ac03d1dfb71c4b456.setContent(html_4e73d982a373240864d1a58fc5b5875b);
#
#
#
#         circle_marker_3622527d8ee644ac46a1264ed23e2609.bindPopup(popup_4f27f5cb124ee12ac03d1dfb71c4b456)
#         ;
#
#
#
#
#             var circle_marker_184f69456a6802a85455541cd8bc8111 = L.circleMarker(
#                 [-23.73, 28.87],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(map_64bc05bbd9693d8aeacf089e409b0a8c);
#
#
#         var popup_0ad49f0ee9f70d6e7d1969a2d880cc99 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fff3d5190948b498fa1aa5541978af50 = $(`&lt;div id=&quot;html_fff3d5190948b498fa1aa5541978af50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Set: train&lt;br&gt;Coordinates: [-23.73, 28.87]&lt;/div&gt;`)[0];
#                 popup_0ad49f0ee9f70d6e7d1969a2d880cc99.setContent(html_fff3d5190948b498fa1aa5541978af50);
#
#
#
#         circle_marker_184f69456a6802a85455541cd8bc8111.bindPopup(popup_0ad49f0ee9f70d6e7d1969a2d880cc99)
#         ;
#
#
#
#
#             var circle_marker_0689fc4170844bdbebebb647528781c8 = L.circleMarker(
#                 [-23.73, 28.97],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(map_64bc05bbd9693d8aeacf089e409b0a8c);
#
#
#         var popup_68a93d2a1dd22d8b30e9b8aca4c23c09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50773822ed3c61d39e09f0dd27d2fb5f = $(`&lt;div id=&quot;html_50773822ed3c61d39e09f0dd27d2fb5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Set: train&lt;br&gt;Coordinates: [-23.73, 28.97]&lt;/div&gt;`)[0];
#                 popup_68a93d2a1dd22d8b30e9b8aca4c23c09.setContent(html_50773822ed3c61d39e09f0dd27d2fb5f);
#
#
#
#         circle_marker_0689fc4170844bdbebebb647528781c8.bindPopup(popup_68a93d2a1dd22d8b30e9b8aca4c23c09)
#         ;
#
#
#
#
#             var circle_marker_2854d9f5d6183a675a6e010b3a8f310e = L.circleMarker(
#                 [-23.73, 29.07],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray

# %% [markdown]
# <a name="Missing"></a>
# ## 6. Missing values and duplicates

# %%
# Check for missing values
train.isnull().sum().any(), test.isnull().sum().any()
# Out:
# (False, False)

# %%
# Plot missing values in train set
ax = train.isna().sum().sort_values(ascending = False)[:15][::-1].plot(kind = 'barh', figsize = (9, 10))
plt.title('Percentage of Missing Values Per Column in Train Set', fontdict={'size':15})
for p in ax.patches:
    percentage ='{:,.0f}%'.format((p.get_width()/train.shape[0])*100)
    width, height =p.get_width(),p.get_height()
    x=p.get_x()+width+0.02
    y=p.get_y()+height/2
    ax.annotate(percentage,(x,y))

# %% [markdown]
# Suggestions on how to handle missing values:
#  - Fill in missing values with mode, mean, median..
#  - Drop Missing datapoints with missing values
#  - Fill in with a large number e.g -999999

# %%
# Check for duplicates
train.duplicated().any(), test.duplicated().any()
# Out:
# (False, False)

# %%
# Dealing with more than 50% missing values
def drop_missing_cols(data, filename):
    missing_cols = []
    
    for col_name, col_values in data.iteritems():
        if col_values.isnull().sum() > (0.5 * data.shape[0]):
            missing_cols.append(col_name)
            
    # list of missing cols
    print(f"Missing cols count for {filename} is {len(missing_cols)}")
    
    # Drop missing cols
    print(f"Dropping {len(missing_cols)} missing cols from {filename}")
    data = data.drop(columns=missing_cols)
    print("Done!")
    
    # Shape of data
    print(f"The shape of {filename} is {data.shape}\n")
    return data
    
# Drop identified columns from the DataFrame
train_drop_missing = drop_missing_cols(train, "train")
test_drop_missing = drop_missing_cols(test, "test")

train = train_drop_missing
test = test_drop_missing
# Out:
# Missing cols count for train is 0
# Dropping 0 missing cols from train
# Done!
# The shape of train is (73800, 70)
#
# Missing cols count for test is 0
# Dropping 0 missing cols from test
# Done!
# The shape of test is (28085, 69)

# %%
# dealing with missing values

# Imputation
final_imputer = SimpleImputer(strategy='mean')
final_X_train = pd.DataFrame(final_imputer.fit_transform(X_train))
final_X_valid = pd.DataFrame(final_imputer.transform(X_valid))

# Imputation removed column names; put them back
final_X_train.columns = X_train.columns
final_X_valid.columns = X_valid.columns


# check for missing values
train.isnull().sum().any(), test.isnull().sum().any()
# Out:
# (True, True)

# %%
# Out:
#    latitude  longitude       year  week_no  \
# 0 -26.33000   27.97000 2019.00000 38.00000
# 1 -31.63000   28.67000 2021.00000 40.00000
# 2 -26.83000   24.97000 2020.00000 44.00000
# 3 -24.23000   29.07000 2022.00000 19.00000
# 4 -28.03000   26.67000 2022.00000 35.00000
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                   0.00005
# 1                                   0.00045
# 2                                  -0.00013
# 3                                   0.00001
# 4                                   0.00020
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                       0.55473
# 1                                       0.51374
# 2                                       0.63661
# 3                                       0.48743
# 4                                       0.44598
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                         0.00002
# 1                                         0.00023
# 2                                        -0.00008
# 3                                         0.00002
# 4                                         0.00005
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  \
# 0                        0.03429                            -43.40834
# 1                        0.08694                             76.51289
# 2                        0.16449                            -43.47652
# 3                        0.18519                             40.41018
# 4                        0.08627                            -10.98378
#
#    SulphurDioxide_sensor_zenith_angle  ...  Cloud_cloud_top_pressure  \
# 0                            28.20192  ...               71655.10807
# 1                            30.47671  ...               68809.80558
# 2                            38.70197  ...               47253.55191
# 3                            34.50361  ...               69439.80982
# 4                            58.16498  ...               67983.26704
#
#    Cloud_cloud_top_height  Cloud_cloud_base_pressure  Cloud_cloud_base_height  \
# 0              3120.27832                73891.98307               2786.94499
# 1              3324.39111                77416.30326               2346.91036
# 2              6528.67178                53762.66972               5528.67202
# 3              3348.51270                77491.68496               2416.83607
# 4              3652.73764                74387.55353               2871.77045
#
#    Cloud_cloud_optical_depth  Cloud_surface_albedo  \
# 0                    5.75414               0.19186
# 1                   83.65918               0.21668
# 2                   19.45014               0.22509
# 3                    9.72724               0.16982
# 4                   15.86383               0.22564
#
#    Cloud_sensor_azimuth_angle  Cloud_sensor_zenith_angle  \
# 0                   -43.38136                   51.49940
# 1                   -14.16171                   59.46393
# 2                    16.38026                   36.21760
# 3                   -13.39703                   29.36929
# 4                   -14.28024                   49.60164
#
#    Cloud_solar_azimuth_angle  Cloud_solar_zenith_angle
# 0                  -51.05871                  41.56738
# 1                  -52.28301                  40.75344
# 2                  -67.21887                  28.50916
# 3                  -33.55991                  50.06210
# 4                  -50.53771                  40.52394
#
# [5 rows x 74 columns]

# %%
train.shape, test.shape
# Out:
# ((73800, 70), (28085, 69))

# %% [markdown]
# <a name="Dates"></a>
# ## 7. Date features EDA

# %%
# Year countplot
plt.figure(figsize = (14, 7))
sns.countplot(x = 'year', data = train)
plt.title('Year count plot')
plt.show()

# %% [markdown]
# - The number of observations of CO2 emissions are relatively the same across the years
# - Year 2022 has fewer number of observations

# %%
# Week countplot
plt.figure(figsize = (14, 7))
sns.countplot(x = 'week_no', data = train)
plt.title('Week count plot')
plt.show()

# %% [markdown]
# - The number of observations of CO2 emissions are relatively the same across the weeks
# - Weeks 49, 50 and 51  have fewer number of observations when compared to the other weeks

# %%
train.drop_duplicates(subset = ['year', 'week_no']).groupby(['year'])[['week_no']].count()
# Out:
#       week_no
# year
# 2019       52
# 2020       52
# 2021       52
# 2022       49

# %% [markdown]
# - The year 2022 has only 49 weeks available in the data

# %% [markdown]
# <a name="Correlations"></a>
# ## 8. Correlations - EDA

# %%
# Top 20 correlated features to the target
top20_corrs = abs(train.corr()['emission']).sort_values(ascending = False).head(20)
top20_corrs
# Out:
# emission                                                 1.00000
# NitrogenDioxide_NO2_column_number_density                0.34615
# NitrogenDioxide_tropospheric_NO2_column_number_density   0.34282
# NitrogenDioxide_NO2_slant_column_number_density          0.33647
# Cloud_surface_albedo                                     0.08672
# longitude                                                0.08384
# SulphurDioxide_SO2_column_number_density_amf             0.06519
# Formaldehyde_HCHO_slant_column_number_density            0.05225
# SulphurDioxide_SO2_column_number_density                 0.05194
# Formaldehyde_tropospheric_HCHO_column_number_density     0.05095
# NitrogenDioxide_cloud_fraction                           0.05040
# SulphurDioxide_SO2_slant_column_number_density           0.04367
# SulphurDioxide_cloud_fraction                            0.04263
# SulphurDioxide_SO2_column_number_density_15km            0.04241
# Formaldehyde_cloud_fraction                              0.04078
# CarbonMonoxide_CO_column_number_density                  0.03763
# UvAerosolIndex_sensor_altitude                           0.03494
# CarbonMonoxide_H2O_column_number_density                 0.03310
# Cloud_solar_azimuth_angle                                0.03212
# CarbonMonoxide_solar_zenith_angle                        0.03174
# Name: emission, dtype: float64

# %%
# Quantify correlations between features
corr = train[list(top20_corrs.index)].corr()
plt.figure(figsize = (13, 8))
sns.heatmap(corr, cmap='RdYlGn', annot = True, center = 0)
plt.title('Correlogram', fontsize = 15, color = 'darkgreen')
plt.show()

# %% [markdown]
# <a name="Timeseries"></a>
# ## 9. Timeseries visualization - EDA

# %%
# Sample a unique location and visualize its emissions across the years
train.latitude, train.longitude = round(train.latitude, 2), round(train.longitude, 2)
sample_loc = train[(train.latitude == -23.73) & (train.longitude == 28.77)]

# Plot a line plot
sns.set_style('darkgrid')
fig, axes = plt.subplots(nrows = 4, ncols = 1, figsize = (13, 10))
fig.suptitle('Co2 emissions for location lat -23.75 lon 28.75', y=1.02, fontsize = 15)

for ax, data, year, color, in zip(axes.flatten(), sample_loc, sample_loc.year.unique(), ['#882255','#332288', '#999933' , 'orangered']):
  df = sample_loc[sample_loc.year == year]
  sns.lineplot(x=df.week_no, y=df.emission, ax = ax, label = year, color = color)
plt.legend()
plt.tight_layout()

# %% [markdown]
# <a name="Engineering"></a>
# ## 10. Feature engineering

# %%
# Examples of feature engineering - Aggregations, cumulative differences, moving averages ...
# Lets explore the rolling mean
# First we create a unique location from lat lon
train['location'] = [str(x) + '_' + str(y) for x, y in zip(train.latitude, train.longitude)]

# Filter based on one location
example_loc = train[train.location == '-23.73_28.77']

# Calculate rolling mean for SulphurDioxide_SO2_column_number_density_amf with a window of 2 weeks
rolling_mean = example_loc['SulphurDioxide_SO2_column_number_density_amf'].rolling(window = 2).mean()

# Visualise rolling mean
plt.figure(figsize = (15, 7))
rolling_mean.plot()
plt.title('Rolling mean with a window of 2 weeks for SulphurDioxide_SO2_column_number_density_amf', y = 1.02, fontsize = 15)
plt.xlabel('week', y = 1.05, fontsize = 13)
plt.ylabel('SulphurDioxide_SO2_column_number_density_amf', x = 1.05, fontsize = 13)
plt.show()

# %% [markdown]
#  - There is a cyclic pattern from the above graph, which clearly shows that there is a pattern - This will be helpful to our model
#  - With more research and domain knowledge generate useful features that can improve your model performance
#
#  Other examples of feature engineering:
#   - Creating cluster regions
#   - Interactions between different pollutatnts - ratios, additions,subtractions...
#   - Time series features

# %%
# Generate the above feature - rolling mean for all locations for both the train and test

# Feature engineering train
train_roll_mean = train.sort_values(by = ['location', 'year', 'week_no']).groupby(['location'])[train.columns[5:].tolist()].rolling(window = 2).mean().reset_index()
train_roll_mean.drop(['level_1', 'emission', 'location'], axis = 1, inplace = True)
train_roll_mean.columns = [col + '_roll_mean' for col in train_roll_mean.columns]

# Feature engineering test
test.latitude, test.longitude = round(test.latitude, 2), round(test.longitude, 2)
test['location'] = [str(x) + '_' + str(y) for x, y in zip(test.latitude, test.longitude)]
test_roll_mean = test.sort_values(by = ['location', 'year', 'week_no']).groupby(['location'])[test.columns[5:].tolist()].rolling(window = 2).mean().reset_index()
test_roll_mean.drop(['level_1', 'location'], axis = 1, inplace = True)
test_roll_mean.columns =  [col + '_roll_mean' for col in test_roll_mean.columns]
test_roll_mean.head()
# Out:
#    SulphurDioxide_SO2_column_number_density_roll_mean  \
# 0                                                NaN
# 1                                            0.00013
# 2                                            0.00012
# 3                                            0.00027
# 4                                            0.00034
#
#    SulphurDioxide_SO2_column_number_density_amf_roll_mean  \
# 0                                                NaN
# 1                                            0.43882
# 2                                            0.56813
# 3                                            0.57377
# 4                                            0.60875
#
#    SulphurDioxide_SO2_slant_column_number_density_roll_mean  \
# 0                                                NaN
# 1                                            0.00005
# 2                                            0.00005
# 3                                            0.00011
# 4                                            0.00016
#
#    SulphurDioxide_cloud_fraction_roll_mean  \
# 0                                      NaN
# 1                                  0.09470
# 2                                  0.09466
# 3                                  0.12280
# 4                                  0.14627
#
#    SulphurDioxide_sensor_azimuth_angle_roll_mean  \
# 0                                            NaN
# 1                                      -49.02600
# 2                                       -0.52002
# 3                                       -2.87484
# 4                                       -8.86249
#
#    SulphurDioxide_sensor_zenith_angle_roll_mean  \
# 0                                           NaN
# 1                                      55.93510
# 2                                      44.99212
# 3                                      47.10618
# 4                                      49.32330
#
#    SulphurDioxide_solar_azimuth_angle_roll_mean  \
# 0                                           NaN
# 1                                     -92.36411
# 2                                     -88.07020
# 3                                     -82.84357
# 4                                     -77.79334
#
#    SulphurDioxide_solar_zenith_angle_roll_mean  \
# 0                                          NaN
# 1                                     26.77170
# 2                                     21.95860
# 3                                     22.25336
# 4                                     22.96216
#
#    SulphurDioxide_SO2_column_number_density_15km_roll_mean  \
# 0                                                NaN
# 1                                            0.00002
# 2                                            0.00002
# 3                                            0.00004
# 4                                            0.00007
#
#    CarbonMonoxide_CO_column_number_density_roll_mean  ...  \
# 0                                                NaN  ...
# 1                                            0.02549  ...
# 2                                            0.02503  ...
# 3                                            0.02369  ...
# 4                                            0.02297  ...
#
#    Cloud_cloud_top_pressure_roll_mean  Cloud_cloud_top_height_roll_mean  \
# 0                                 NaN                               NaN
# 1                         79559.85276                        1581.44280
# 2                         81572.57215                        1282.79200
# 3                         70029.20519                        2759.19246
# 4                         69815.08349                        2791.47925
#
#    Cloud_cloud_base_pressure_roll_mean  Cloud_cloud_base_height_roll_mean  \
# 0                                  NaN                                NaN
# 1                          85797.36225                         1244.57112
# 2                          87845.40093                          966.94467
# 3                          76436.59161                         2217.60082
# 4                          75984.38720                         2275.47881
#
#    Cloud_cloud_optical_depth_roll_mean  Cloud_surface_albedo_roll_mean  \
# 0                                  NaN                             NaN
# 1                              7.99207                         0.25980
# 2                              6.03470                         0.24881
# 3                              6.52650                         0.27011
# 4                              9.02194                         0.28155
#
#    Cloud_sensor_azimuth_angle_roll_mean  Cloud_sensor_zenith_angle_roll_mean  \
# 0                                   NaN                                  NaN
# 1                              17.63036                             45.73788
# 2                              71.20704                             49.73737
# 3                              32.44998                             51.01341
# 4                             -12.15887                             55.84850
#
#    Cloud_solar_azimuth_angle_roll_mean  Cloud_solar_zenith_angle_roll_mean
# 0                                  NaN                                 NaN
# 1                            -89.10936                            18.38737
# 2                            -84.13451                            14.84474
# 3                            -80.51563                            19.53348
# 4                            -77.19218                            22.99610
#
# [5 rows x 63 columns]

# %%
# Merge engineered features with train and test set

#Train
train_eng = train.sort_values(by = ['location', 'year', 'week_no'], ignore_index = True).merge(train_roll_mean, how = 'left',
                                                                                               left_index=True, right_index=True)

# Test
test_eng = test.sort_values(by = ['location', 'year', 'week_no'], ignore_index = True).merge(test_roll_mean, how = 'left',
                                                                                               left_index=True, right_index=True)

# Preview engineered test set
test_eng.head()
# Out:
#      ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-23.53_27.47_2019_1 -23.53000   27.47000  2019        1
# 1  ID_-23.53_27.47_2019_2 -23.53000   27.47000  2019        2
# 2  ID_-23.53_27.47_2019_3 -23.53000   27.47000  2019        3
# 3  ID_-23.53_27.47_2019_4 -23.53000   27.47000  2019        4
# 4  ID_-23.53_27.47_2019_5 -23.53000   27.47000  2019        5
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                   0.00008
# 1                                   0.00018
# 2                                   0.00006
# 3                                   0.00048
# 4                                   0.00019
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                       0.45447
# 1                                       0.42317
# 2                                       0.71309
# 3                                       0.43445
# 4                                       0.78304
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                         0.00003
# 1                                         0.00006
# 2                                         0.00004
# 3                                         0.00017
# 4                                         0.00014
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  ...  \
# 0                        0.11429                            -80.28631  ...
# 1                        0.07510                            -17.76569  ...
# 2                        0.11421                             16.72565  ...
# 3                        0.13139                            -22.47534  ...
# 4                        0.16114                              4.75036  ...
#
#    Cloud_cloud_top_pressure_roll_mean  Cloud_cloud_top_height_roll_mean  \
# 0                                 NaN                               NaN
# 1                         79559.85276                        1581.44280
# 2                         81572.57215                        1282.79200
# 3                         70029.20519                        2759.19246
# 4                         69815.08349                        2791.47925
#
#    Cloud_cloud_base_pressure_roll_mean  Cloud_cloud_base_height_roll_mean  \
# 0                                  NaN                                NaN
# 1                          85797.36225                         1244.57112
# 2                          87845.40093                          966.94467
# 3                          76436.59161                         2217.60082
# 4                          75984.38720                         2275.47881
#
#    Cloud_cloud_optical_depth_roll_mean  Cloud_surface_albedo_roll_mean  \
# 0                                  NaN                             NaN
# 1                              7.99207                         0.25980
# 2                              6.03470                         0.24881
# 3                              6.52650                         0.27011
# 4                              9.02194                         0.28155
#
#    Cloud_sensor_azimuth_angle_roll_mean  Cloud_sensor_zenith_angle_roll_mean  \
# 0                                   NaN                                  NaN
# 1                              17.63036                             45.73788
# 2                              71.20704                             49.73737
# 3                              32.44998                             51.01341
# 4                             -12.15887                             55.84850
#
#    Cloud_solar_azimuth_angle_roll_mean  Cloud_solar_zenith_angle_roll_mean
# 0                                  NaN                                 NaN
# 1                            -89.10936                            18.38737
# 2                            -84.13451                            14.84474
# 3                            -80.51563                            19.53348
# 4                            -77.19218                            22.99610
#
# [5 rows x 132 columns]

# %% [markdown]
# <a name="Modelling"></a>
# ## 11.  Modelling

# %%
# Selecting the independent variables and the target variable

X = train_eng.drop(['ID_LAT_LON_YEAR_WEEK', 'location', 'emission'], axis = 1)
y = train_eng.emission

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = SEED)

# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='mean')

# preprocessor transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, X_train.columns),
    ])

# Instantiating the model
clf = RandomForestRegressor(n_estimators=100, random_state=SEED, n_jobs=-1)

# Bundle preprocessing and modeling code in a pipeline
my_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                              ('clf', clf)
                             ])

# Preprocessing of training data, fit model 
my_pipeline.fit(X_train, y_train)

# Making predictions
y_pred = my_pipeline.predict(X_test)

# Measuring the accuracy of the model
print(f'RMSE Score: {mean_squared_error(y_test, y_pred, squared=False)}') # 23432.342352754695
# Out:
# RMSE Score: 2875.6700736015578

# %%
X_test.head()
# Out:
#        latitude  longitude  year  week_no  \
# 25246 -26.23000   28.27000  2019       32
# 28217 -26.83000   24.77000  2021       29
# 70057 -31.93000   29.07000  2021       49
# 31793 -27.13000   24.77000  2019       19
# 14879 -24.43000   28.97000  2021       16
#
#        SulphurDioxide_SO2_column_number_density  \
# 25246                                   0.00069
# 28217                                   0.00338
# 70057                                   0.00051
# 31793                                   0.00070
# 14879                                  -0.00014
#
#        SulphurDioxide_SO2_column_number_density_amf  \
# 25246                                       0.35326
# 28217                                       0.34260
# 70057                                       0.48566
# 31793                                       0.34213
# 14879                                       0.67332
#
#        SulphurDioxide_SO2_slant_column_number_density  \
# 25246                                         0.00022
# 28217                                         0.00115
# 70057                                         0.00024
# 31793                                         0.00025
# 14879                                        -0.00006
#
#        SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  \
# 25246                        0.14950                             68.33937
# 28217                        0.19007                            -84.82139
# 70057                        0.00000                             16.96388
# 31793                        0.09678                              4.35319
# 14879                        0.10530                              4.46093
#
#        SulphurDioxide_sensor_zenith_angle  ...  \
# 25246                            51.17023  ...
# 28217                            58.12186  ...
# 70057                            23.54265  ...
# 31793                            41.42902  ...
# 14879                            27.16227  ...
#
#        Cloud_cloud_top_pressure_roll_mean  Cloud_cloud_top_height_roll_mean  \
# 25246                         74228.34275                        2783.98498
# 28217                         57847.23371                        4722.93360
# 70057                         74583.28045                        3102.79313
# 31793                         69569.94630                        3328.11670
# 14879                         69727.46884                        3290.96503
#
#        Cloud_cloud_base_pressure_roll_mean  Cloud_cloud_base_height_roll_mean  \
# 25246                          78207.69246                         2256.91871
# 28217                          64992.36585                         3785.95729
# 70057                          83357.41266                         2143.92831
# 31793                          75479.49771                         2603.88982
# 14879                          78363.53089                         2319.57043
#
#        Cloud_cloud_optical_depth_roll_mean  Cloud_surface_albedo_roll_mean  \
# 25246                              4.21881                         0.13374
# 28217                              6.09404                         0.20408
# 70057                             54.82349                         0.33451
# 31793                              4.61779                         0.19704
# 14879                             15.95811                         0.19061
#
#        Cloud_sensor_azimuth_angle_roll_mean  \
# 25246                              -7.91848
# 28217                              31.17496
# 70057                             -30.65248
# 31793                             -24.72469
# 14879                              -8.50463
#
#        Cloud_sensor_zenith_angle_roll_mean  \
# 25246                             57.08447
# 28217                             53.42689
# 70057                             54.38783
# 31793                             46.34682
# 14879                             54.51708
#
#        Cloud_solar_azimuth_angle_roll_mean  Cloud_solar_zenith_angle_roll_mean
# 25246                            -30.81011                            50.70806
# 28217                            -32.48450                            45.44824
# 70057                            -77.76871                            30.40632
# 31793                            -34.58688                            51.87101
# 14879                            -36.96832                            44.91950
#
# [5 rows x 130 columns]

# %%
# Analyse predictions
pred_errors = X_test.copy()
pred_errors['emission'] = y_test
pred_errors['prediction'] = y_pred
pred_errors['error'] = abs(pred_errors.prediction - pred_errors.emission)
pred_errors = pred_errors[['latitude',	'longitude',	'year',	'week_no', 'emission', 'prediction', 'error']]
pred_errors.sort_values(by = 'error', ascending = False, inplace = True)
pred_errors.head()
# Out:
#        latitude  longitude  year  week_no     emission   prediction  \
# 23384 -26.13000   28.27000  2019       15 244604.03000 108223.44977
# 23419 -26.13000   28.27000  2019       50 227980.55000  98140.03331
# 23524 -26.13000   28.27000  2021       51 196896.38000  84853.00335
# 23571 -26.13000   28.27000  2022       46 179724.12000  78381.83999
# 23435 -26.13000   28.27000  2020       14 190726.62000  89915.28734
#
#              error
# 23384 136380.58023
# 23419 129840.51669
# 23524 112043.37665
# 23571 101342.28001
# 23435 100811.33266

# %%
pred_errors.tail()
# Out:
#        latitude  longitude  year  week_no  emission  prediction   error
# 38901 -28.23000   21.37000  2022        1   0.58388     0.58352 0.00036
# 43946 -28.63000   21.47000  2020       25   1.39036     1.39060 0.00024
# 32544 -27.23000   24.47000  2021       51   0.95396     0.95418 0.00022
# 36957 -28.13000   21.37000  2020        6   0.81648     0.81654 0.00006
# 41006 -28.43000   21.07000  2019        7   2.10603     2.10609 0.00005

# %%
pred_errors.describe()
# Out:
#          latitude   longitude        year     week_no     emission  \
# count 22140.00000 22140.00000 22140.00000 22140.00000  22140.00000
# mean    -27.83949    27.80890  2020.47602    26.25443   5261.39016
# std       2.77126     2.72647     1.10798    14.79727  15921.33760
# min     -33.93000    21.07000  2019.00000     1.00000      0.04965
# 25%     -29.63000    26.67000  2019.00000    14.00000    156.36838
# 50%     -28.13000    28.77000  2020.00000    26.00000    726.92157
# 75%     -25.73000    29.47000  2021.00000    39.00000   2745.68872
# max     -23.73000    31.17000  2022.00000    52.00000 268914.34000
#
#         prediction        error
# count  22140.00000  22140.00000
# mean    5310.76376    583.97633
# std    15366.38643   2815.81394
# min        0.05663      0.00005
# 25%      168.16019      5.88935
# 50%      794.76245     35.43720
# 75%     3141.77668    215.95876
# max   262466.35310 136380.58023

# %%
train.emission.describe()
# Out:
# count    73800.00000
# mean      5269.34656
# std      15782.85966
# min          0.04806
# 25%        153.92712
# 50%        719.14458
# 75%       2721.42803
# max     271520.10000
# Name: emission, dtype: float64

# %%
# Feature importance
impo_df = pd.DataFrame({'feature': X.columns, 'importance': clf.feature_importances_}).set_index('feature').sort_values(by = 'importance', ascending = False)
impo_df = impo_df[:12].sort_values(by = 'importance', ascending = True)
impo_df.plot(kind = 'barh', figsize = (10, 10))
plt.legend(loc = 'center right')
plt.title('Bar chart showing feature importance', fontsize = 14)
plt.xlabel('Features', fontsize = 12)
plt.show()

# %% [markdown]
# <a name="Predictions"></a>
# ## 12. Making predictions of the test set and creating a submission file

# %%
# Make prediction on the test set
test_df = test_eng.drop(['ID_LAT_LON_YEAR_WEEK', 'location'], axis = 1).fillna(0)
predictions = clf.predict(test_df)

# # Create a submission file
sub_file = pd.DataFrame({'ID_LAT_LON_YEAR_WEEK': test_eng.ID_LAT_LON_YEAR_WEEK, 'emission': predictions})
sub_file.head()
# Out:
#      ID_LAT_LON_YEAR_WEEK   emission
# 0  ID_-23.53_27.47_2019_1 3115.04926
# 1  ID_-23.53_27.47_2019_2 2584.71495
# 2  ID_-23.53_27.47_2019_3 2643.21933
# 3  ID_-23.53_27.47_2019_4 2857.57661
# 4  ID_-23.53_27.47_2019_5 4010.23307

# %%
# Create file
sub_file.to_csv('BaselineSubmission.csv', index = False) # Download subfile and submit to zindi for scoring

# %% [markdown]
# ## ALL THE BEST AND HAVE FUN &#x1F60E;
